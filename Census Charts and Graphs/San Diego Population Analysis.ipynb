# %%
# %matplotlib inline

# %%
# Dependencies
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the file
census_data = "../sdhousing_csv.csv"

# Read in the file with Pandas
census_data_df = pd.read_csv(census_data)

# Display the data table for preview
census_data_df.head()
# Out:
#      zip                GEO_NAME  pop_2011  pop_2014  pop_2017 med_hh_inc_11  \
# 0  91901       Alpine California     16606     18184     18238         77064
# 1  91902       Bonita California     17399     19504     19762         78187
# 2  91910  Chula Vista California     71887     76797     76250         56510
# 3  91911  Chula Vista California     79518     83710     84025         48386
# 4  91913  Chula Vista California     40633     43655     49346         89737
#
#   med_hh_inc_14 med_hh_inc_17  total_units_11  total_units_14  \
# 0         81379         90397           16104           17782
# 1         88926         92759           17379           19456
# 2         54640         59371           71070           75863
# 3         48891         52274           79101           83057
# 4         84741         87440           40633           43650
#
#           ...           ownocc_units_17  rent_units_11  rent_units_14  \
# ...

# %%
# Calculate the
